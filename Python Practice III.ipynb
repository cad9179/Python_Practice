# %% [markdown]
# # Python Practice III
#
# ##  Matplotlib
#
# 1. Plot $ y = x, y=x^2, y=x^3 $ , where x in [0,2]. Use 100 points in line space.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2)
y = (x) 
y2 = (x**2)
y3 = (x**3)

plt.plot(x, y, '-b', label=r'linear')
plt.plot(x, y2, color='tab:orange', label=r'quadratic')
plt.plot(x, y3, '-g', label=r'cubic')

axes = plt.gca()
axes.set_ylim([0, 8])

plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Simple Plot')
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# 2. Ploy pie chart for programming languge distribution:
#     [Jave, R, Python, C#] = [15%,30%,45%,10%] . Explode 0.1.

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ('java', 'R', 'Python', 'C#')
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 

plt.show()

# %% [markdown]
# 3. Plot bar char for programming language performance.
# [Python, C++, Jave, Perl, Scala, Lisp]=[10,8,6,4,2,1].
# Hint: Define list for languges and performance.

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5, color="salmon")
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()
